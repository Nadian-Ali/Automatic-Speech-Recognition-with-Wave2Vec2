# %%
import numpy as np

# %%
from scipy.io import wavfile

# %%
samplerate, data = wavfile.read('./snd.wav')

# %%
import librosa

# %%
list(data)
# Out:
# [3,
#  7,
#  0,
#  5,
#  7,
#  4,
#  3,
#  7,
#  5,
#  5,
#  2,
#  3,
#  -1,
#  0,
#  4,
#  2,
#  -2,
#  -1,
#  1,
#  1,
#  1,
#  -2,
#  -2,
#  1,
#  2,
#  -4,
#  -4,
#  0,
#  -2,
#  -3,
#  -2,
#  -1,
#  -3,
#  -6,
#  -7,
#  -5,
#  -3,
#  -3,
#  -5,
#  -4,
#  -8,
#  -5,
#  -9,
#  -8,
#  -8,
#  -6,
#  -9,
#  -11,
#  -13,
#  -11,
#  -12,
#  -11,
#  -12,
#  -12,
#  -10,
#  -11,
#  -13,
#  -14,
#  -9,
#  -13,
#  -9,
#  -9,
#  -12,
#  -16,
#  -14,
#  -19,
#  -15,
#  -16,
#  -13,
#  -16,
#  -15,
#  -16,
#  -16,
#  -14,
#  -14,
#  -17,
#  -18,
#  -14,
#  -15,
#  -21,
#  -19,
#  -15,
#  -19,
#  -18,
#  -20,
#  -17,
#  -19,
#  -19,
#  -22,
#  -19,
#  -19,
#  -21,
#  -22,
#  -23,
#  -20,
#  -23,
#  -22,
#  -27,
#  -21,
#  -22,
#  -23,
#  -24,
#  -26,
#  -26,
#  -25,
#  -22,
#  -25,
#  -22,
#  -27,
#  -23,
#  -24,
#  -24,
#  -26,
#  -25,
#  -22,
#  -24,
#  -24,
#  -21,
#  -24,
#  -23,
#  -23,
#  -24,
#  -21,
#  -23,
#  -24,
#  -23,
#  -22,
#  -24,
#  -23,
#  -25,
#  -22,
#  -21,
#  -23,
# ...
